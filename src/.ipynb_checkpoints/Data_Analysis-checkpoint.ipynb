# %% [markdown]
# # City of Los Angeles Crime Data from 2020 to Present

# %% [markdown]
# ## Dataset Information

# %% [markdown]
# Dataset is from LOS ANGELES OPEN DATA. You can access the official website with this link:  https://data.lacity.org/

# %% [markdown]
# Los Angeles Police Department. “Crime Data from 2020 to Present.” Public Safety | Los Angeles - Open Data Portal, 11 Oct. 2023, https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8

# %% [markdown]
# ## Libraries Used

# %%
# Import necessary libraries

import pandas as pd # Import pandas for data manipulation

import matplotlib.pyplot as plt  # Import matplotlib library for plotting

from wordcloud import WordCloud # Used to create word cloud visualizations based on frequency data

import folium # Used for creating the map visualization

from folium.plugins import MarkerCluster  # Used for clustering markers on the map

import seaborn as sns # Import the Seaborn data visualization library

import calendar

from datetime import datetime

# %% [markdown]
# ## Accessing Dataset

# %%
# You can access the dataset here: https://data.lacity.org/Public-Safety/Crime-Data-from-2020-to-Present/2nrs-mtv8

# CSV file path
csv_file_path = '/home/pumpkins/Development/programmingPythonCourse/Final/Crime_Data_from_2020_to_Present.csv'  

# Load the CSV file into a DataFrame
crime = pd.read_csv(csv_file_path)

# Display the shape of the DataFrame
print(crime.shape)
# Out:
# (838901, 28)

# %%
# Display the first few rows of the 'crime' DataFrame to get a quick look at the data
# Set display options to show all rows and columns
# pd.set_option('display.max_rows', 838901)
# pd.set_option('display.max_columns', 28)

crime.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0   10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230     3
# 1  190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330     1
# 2  200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200     1
# 3  191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730    15
# 4  191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415    19
#
#      AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0    Southwest          377         2     624
# 1      Central          163         2     624
# 2      Central          155         2     845
# 3  N Hollywood         1543         2     745
# 4      Mission         1998         2     740
#
#                                          Crm Cd Desc         Mocodes  \
# 0                           BATTERY - SIMPLE ASSAULT       0444 0913
# 1                           BATTERY - SIMPLE ASSAULT  0416 1822 1414
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE            1501
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)       0329 1402
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            0329
#
#    Vict Age Vict Sex Vict Descent  Premis Cd  \
# 0        36        F            B      501.0
# 1        25        M            H      102.0
# 2         0        X            X      726.0
# 3        76        F            W      502.0
# 4        31        X            X      409.0
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                        SINGLE FAMILY DWELLING           400.0
# 1                                      SIDEWALK           500.0
# 2                               POLICE FACILITY             NaN
# 3  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 4                           BEAUTY SUPPLY STORE             NaN
#
#                                       Weapon Desc Status   Status Desc  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO   Adult Other
# 1                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 2                                             NaN     AA  Adult Arrest
# 3                                             NaN     IC   Invest Cont
# 4                                             NaN     IC   Invest Cont
#
#    Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  \
# 0     624.0       NaN       NaN       NaN
# 1     624.0       NaN       NaN       NaN
# 2     845.0       NaN       NaN       NaN
# 3     745.0     998.0       NaN       NaN
# 4     740.0       NaN       NaN       NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2    200 E  6TH                          ST          NaN  34.0448 -118.2474
# 3   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 4  14400    TITUS                        ST          NaN  34.2198 -118.4468

# %% [markdown]
# ## Description of Columns in this Dataset:
#
# DR_NO: Unique incident identifier.
#
# Date Rptd: Date when the incident was reported.
#
# DATE OCC: Date when the incident occurred.
#
# TIME OCC: Time of day when the incident occurred.
#
# AREA: Numeric code indicating the incident area. The LAPD has 21 Community Police Stations referred to as Geographic Areas within the department. These Geographic Areas are sequentially numbered from 1-21
#
# AREA NAME: Name of the incident area. The 21 Geographic Areas or Patrol Divisions are also given a name designation that references a landmark or the surrounding community that it is responsible for.
#
# Rpt Dist No: Reporting district within the area.
#
# Part 1-2: Classification of the incident as Part 1 or Part 2 crime.
#
# Crm Cd: Numeric code for the type of crime.
#
# Crm Cd Desc: Description of the crime.
#
# Mocodes: Codes describing the modus operandi of the crime.
#
# Vict Age, Vict Sex, Vict Descent: Victim demographics.
#
# Premis Cd: Numeric code for the type of structure, vehicle, or location where the crime took place.
#
# Premis Desc: Description of the incident location.
#
# Weapon Used Cd: Code indicating weapon use.
#
# Weapon Desc: Description of the weapon used.
#
# Status: Incident status.
#
# Status Desc: Description of the incident status.
#
# Crm Cd 1-4: Additional related crime codes.
#
# LOCATION: Approximate incident location.
#
# Cross Street: Nearest cross street.
#
# LAT: Latitude coordinate.
#
# LON: Longitude coordinate.

# %% [markdown]
# ## Dataset Exploration

# %%
# Generate statistical summary for all columns in the 'crime' DataFrame, including non-numeric ones

crime.describe(include='all', datetime_is_numeric=True)
# Out:
#                DR_NO               Date Rptd                DATE OCC  \
# count   8.389010e+05                  838901                  838901
# unique           NaN                    1413                    1413
# top              NaN  02/03/2023 12:00:00 AM  12/02/2022 12:00:00 AM
# freq             NaN                     924                    1130
# mean    2.164559e+08                     NaN                     NaN
# std     1.093217e+07                     NaN                     NaN
# min     8.170000e+02                     NaN                     NaN
# 25%     2.102122e+08                     NaN                     NaN
# 50%     2.202064e+08                     NaN                     NaN
# 75%     2.221087e+08                     NaN                     NaN
# max     2.399306e+08                     NaN                     NaN
#
#              TIME OCC           AREA AREA NAME    Rpt Dist No       Part 1-2  \
# count   838901.000000  838901.000000    838901  838901.000000  838901.000000
# unique            NaN            NaN        21            NaN            NaN
# top               NaN            NaN   Central            NaN            NaN
# freq              NaN            NaN     56587            NaN            NaN
# mean      1336.037708      10.707783       NaN    1117.203024       1.413325
# std        653.873079       6.095439       NaN     609.537820       0.492430
# min          1.000000       1.000000       NaN     101.000000       1.000000
# 25%        900.000000       6.000000       NaN     615.000000       1.000000
# 50%       1415.000000      11.000000       NaN    1141.000000       1.000000
# 75%       1900.000000      16.000000       NaN    1615.000000       2.000000
# max       2359.000000      21.000000       NaN    2199.000000       2.000000
#
#                Crm Cd       Crm Cd Desc Mocodes       Vict Age Vict Sex  \
# count   838901.000000            838901  722647  838901.000000   728346
# unique            NaN               138  279050            NaN        5
# top               NaN  VEHICLE - STOLEN    0344            NaN        M
# freq              NaN             89929   34189            NaN   345942
# mean       500.825741               NaN     NaN      29.777582      NaN
# std        207.770586               NaN     NaN      21.787422      NaN
# min        110.000000               NaN     NaN      -3.000000      NaN
# 25%        331.000000               NaN     NaN       6.000000      NaN
# 50%        442.000000               NaN     NaN      31.000000      NaN
# 75%        626.000000               NaN     NaN      45.000000      NaN
# max        956.000000               NaN     NaN     120.000000      NaN
#
#        Vict Descent      Premis Cd Premis Desc  Weapon Used Cd  \
# count        728338  838891.000000      838395   292391.000000
# unique           20            NaN         306             NaN
# top               H            NaN      STREET             NaN
# freq         257152            NaN      212428             NaN
# mean            NaN     305.884657         NaN      363.123372
# std             NaN     216.863443         NaN      123.700408
# min             NaN     101.000000         NaN      101.000000
# 25%             NaN     101.000000         NaN      310.000000
# 50%             NaN     203.000000         NaN      400.000000
# 75%             NaN     501.000000         NaN      400.000000
# max             NaN     976.000000         NaN      516.000000
#
#                                            Weapon Desc  Status  Status Desc  \
# count                                           292391  838901       838901
# unique                                              79       6            6
# top     STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)      IC  Invest Cont
# freq                                            156686  671291       671291
# mean                                               NaN     NaN          NaN
# std                                                NaN     NaN          NaN
# min                                                NaN     NaN          NaN
# 25%                                                NaN     NaN          NaN
# 50%                                                NaN     NaN          NaN
# 75%                                                NaN     NaN          NaN
# max                                                NaN     NaN          NaN
#
#              Crm Cd 1      Crm Cd 2     Crm Cd 3    Crm Cd 4  \
# count   838890.000000  61634.000000  2081.000000   61.000000
# unique            NaN           NaN          NaN         NaN
# top               NaN           NaN          NaN         NaN
# freq              NaN           NaN          NaN         NaN
# mean       500.564774    957.544245   983.831331  990.868852
# std        207.558394    111.323355    52.426413   27.690236
# min        110.000000    210.000000   310.000000  821.000000
# 25%        331.000000    998.000000   998.000000  998.000000
# 50%        442.000000    998.000000   998.000000  998.000000
# 75%        626.000000    998.000000   998.000000  998.000000
# max        956.000000    999.000000   999.000000  999.000000
#
#                                       LOCATION Cross Street            LAT  \
# count                                   838901       133812  838901.000000
# unique                                   64053         9781            NaN
# top     800 N  ALAMEDA                      ST     BROADWAY            NaN
# freq                                      1527         2218            NaN
# mean                                       NaN          NaN      33.981623
# std                                        NaN          NaN       1.770806
# min                                        NaN          NaN       0.000000
# 25%                                        NaN          NaN      34.013800
# 50%                                        NaN          NaN      34.058400
# 75%                                        NaN          NaN      34.163100
# max                                        NaN          NaN      34.334300
#
#                   LON
# count   838901.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean      -118.034743
# std          6.139685
# min       -118.667600
# 25%       -118.429600
# 50%       -118.321500
# 75%       -118.273900
# max          0.000000

# %%
# Display information about the 'crime' DataFrame, including data types and non-null counts
# This is useful for understanding the dataset's structure and checking for missing values

crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838901 entries, 0 to 838900
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           838901 non-null  int64
#  1   Date Rptd       838901 non-null  object
#  2   DATE OCC        838901 non-null  object
#  3   TIME OCC        838901 non-null  int64
#  4   AREA            838901 non-null  int64
#  5   AREA NAME       838901 non-null  object
#  6   Rpt Dist No     838901 non-null  int64
#  7   Part 1-2        838901 non-null  int64
#  8   Crm Cd          838901 non-null  int64
#  9   Crm Cd Desc     838901 non-null  object
#  10  Mocodes         722647 non-null  object
#  11  Vict Age        838901 non-null  int64
#  12  Vict Sex        728346 non-null  object
#  13  Vict Descent    728338 non-null  object
#  14  Premis Cd       838891 non-null  float64
#  15  Premis Desc     838395 non-null  object
#  16  Weapon Used Cd  292391 non-null  float64
#  17  Weapon Desc     292391 non-null  object
#  18  Status          838901 non-null  object
#  19  Status Desc     838901 non-null  object
#  20  Crm Cd 1        838890 non-null  float64
#  21  Crm Cd 2        61634 non-null   float64
#  22  Crm Cd 3        2081 non-null    float64
#  23  Crm Cd 4        61 non-null      float64
#  24  LOCATION        838901 non-null  object
#  25  Cross Street    133812 non-null  object
#  26  LAT             838901 non-null  float64
#  27  LON             838901 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 179.2+ MB

# %% [markdown]
# ## Data Cleaning

# %%
# Convert the columns in the 'crime' DataFrame to the correct data type
crime['Date Rptd'] = crime['Date Rptd'].astype('datetime64[ns]')
crime['DATE OCC'] = crime['DATE OCC'].astype('datetime64[ns]')

# %%
# Convert 'TIME OCC' column to string type
crime['TIME OCC'] = crime['TIME OCC'].astype(str)

# Ensure all times are of length 4, filling with leading zeroes if necessary
crime['TIME OCC'] = crime['TIME OCC'].str.zfill(4)

# Insert a colon ':' between hours and minutes
crime['TIME OCC'] = crime['TIME OCC'].str.replace(r'(\d{2})(\d{2})', r'\1:\2', regex=True)

# %%
# Display info after conversion
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838901 entries, 0 to 838900
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           838901 non-null  int64
#  1   Date Rptd       838901 non-null  datetime64[ns]
#  2   DATE OCC        838901 non-null  datetime64[ns]
#  3   TIME OCC        838901 non-null  object
#  4   AREA            838901 non-null  int64
#  5   AREA NAME       838901 non-null  object
#  6   Rpt Dist No     838901 non-null  int64
#  7   Part 1-2        838901 non-null  int64
#  8   Crm Cd          838901 non-null  int64
#  9   Crm Cd Desc     838901 non-null  object
#  10  Mocodes         722647 non-null  object
#  11  Vict Age        838901 non-null  int64
#  12  Vict Sex        728346 non-null  object
#  13  Vict Descent    728338 non-null  object
#  14  Premis Cd       838891 non-null  float64
#  15  Premis Desc     838395 non-null  object
#  16  Weapon Used Cd  292391 non-null  float64
#  17  Weapon Desc     292391 non-null  object
#  18  Status          838901 non-null  object
#  19  Status Desc     838901 non-null  object
#  20  Crm Cd 1        838890 non-null  float64
#  21  Crm Cd 2        61634 non-null   float64
#  22  Crm Cd 3        2081 non-null    float64
#  23  Crm Cd 4        61 non-null      float64
#  24  LOCATION        838901 non-null  object
#  25  Cross Street    133812 non-null  object
#  26  LAT             838901 non-null  float64
#  27  LON             838901 non-null  float64
# dtypes: datetime64[ns](2), float64(8), int64(6), object(12)
# memory usage: 179.2+ MB

# %%
crime.head()
# Out:
#        DR_NO  Date Rptd   DATE OCC TIME OCC  AREA    AREA NAME  Rpt Dist No  \
# 0   10304468 2020-01-08 2020-01-08    22:30     3    Southwest          377
# 1  190101086 2020-01-02 2020-01-01    03:30     1      Central          163
# 2  200110444 2020-04-14 2020-02-13    12:00     1      Central          155
# 3  191501505 2020-01-01 2020-01-01    17:30    15  N Hollywood         1543
# 4  191921269 2020-01-01 2020-01-01    04:15    19      Mission         1998
#
#    Part 1-2  Crm Cd                                        Crm Cd Desc  \
# 0         2     624                           BATTERY - SIMPLE ASSAULT
# 1         2     624                           BATTERY - SIMPLE ASSAULT
# 2         2     845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3         2     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4         2     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#           Mocodes  Vict Age Vict Sex Vict Descent  Premis Cd  \
# 0       0444 0913        36        F            B      501.0
# 1  0416 1822 1414        25        M            H      102.0
# 2            1501         0        X            X      726.0
# 3       0329 1402        76        F            W      502.0
# 4            0329        31        X            X      409.0
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                        SINGLE FAMILY DWELLING           400.0
# 1                                      SIDEWALK           500.0
# 2                               POLICE FACILITY             NaN
# 3  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 4                           BEAUTY SUPPLY STORE             NaN
#
#                                       Weapon Desc Status   Status Desc  \
# 0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO   Adult Other
# 1                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 2                                             NaN     AA  Adult Arrest
# 3                                             NaN     IC   Invest Cont
# 4                                             NaN     IC   Invest Cont
#
#    Crm Cd 1  Crm Cd 2  Crm Cd 3  Crm Cd 4  \
# 0     624.0       NaN       NaN       NaN
# 1     624.0       NaN       NaN       NaN
# 2     845.0       NaN       NaN       NaN
# 3     745.0     998.0       NaN       NaN
# 4     740.0       NaN       NaN       NaN
#
#                                    LOCATION Cross Street      LAT       LON
# 0   1100 W  39TH                         PL          NaN  34.0141 -118.2978
# 1    700 S  HILL                         ST          NaN  34.0459 -118.2545
# 2    200 E  6TH                          ST          NaN  34.0448 -118.2474
# 3   5400    CORTEEN                      PL          NaN  34.1685 -118.4019
# 4  14400    TITUS                        ST          NaN  34.2198 -118.4468

# %%
# Generate statistical summary for all columns in the 'crime' DataFrame, including non-numeric ones

crime.describe(include='all', datetime_is_numeric=True)
# Out:
#                DR_NO                      Date Rptd  \
# count   8.389010e+05                         838901
# unique           NaN                            NaN
# top              NaN                            NaN
# freq             NaN                            NaN
# mean    2.164559e+08  2022-01-08 02:15:21.322539008
# min     8.170000e+02            2020-01-01 00:00:00
# 25%     2.102122e+08            2021-02-02 00:00:00
# 50%     2.202064e+08            2022-02-01 00:00:00
# 75%     2.221087e+08            2022-12-20 00:00:00
# max     2.399306e+08            2023-11-13 00:00:00
# std     1.093217e+07                            NaN
#
#                              DATE OCC TIME OCC           AREA AREA NAME  \
# count                          838901   838901  838901.000000    838901
# unique                            NaN     1439            NaN        21
# top                               NaN    12:00            NaN   Central
# freq                              NaN    29807            NaN     56587
# mean    2021-12-28 11:38:04.742061312      NaN      10.707783       NaN
# min               2020-01-01 00:00:00      NaN       1.000000       NaN
# 25%               2021-01-19 00:00:00      NaN       6.000000       NaN
# 50%               2022-01-18 00:00:00      NaN      11.000000       NaN
# 75%               2022-12-08 00:00:00      NaN      16.000000       NaN
# max               2023-11-13 00:00:00      NaN      21.000000       NaN
# std                               NaN      NaN       6.095439       NaN
#
#           Rpt Dist No       Part 1-2         Crm Cd       Crm Cd Desc Mocodes  \
# count   838901.000000  838901.000000  838901.000000            838901  722647
# unique            NaN            NaN            NaN               138  279050
# top               NaN            NaN            NaN  VEHICLE - STOLEN    0344
# freq              NaN            NaN            NaN             89929   34189
# mean      1117.203024       1.413325     500.825741               NaN     NaN
# min        101.000000       1.000000     110.000000               NaN     NaN
# 25%        615.000000       1.000000     331.000000               NaN     NaN
# 50%       1141.000000       1.000000     442.000000               NaN     NaN
# 75%       1615.000000       2.000000     626.000000               NaN     NaN
# max       2199.000000       2.000000     956.000000               NaN     NaN
# std        609.537820       0.492430     207.770586               NaN     NaN
#
#              Vict Age Vict Sex Vict Descent      Premis Cd Premis Desc  \
# count   838901.000000   728346       728338  838891.000000      838395
# unique            NaN        5           20            NaN         306
# top               NaN        M            H            NaN      STREET
# freq              NaN   345942       257152            NaN      212428
# mean        29.777582      NaN          NaN     305.884657         NaN
# min         -3.000000      NaN          NaN     101.000000         NaN
# 25%          6.000000      NaN          NaN     101.000000         NaN
# 50%         31.000000      NaN          NaN     203.000000         NaN
# 75%         45.000000      NaN          NaN     501.000000         NaN
# max        120.000000      NaN          NaN     976.000000         NaN
# std         21.787422      NaN          NaN     216.863443         NaN
#
#         Weapon Used Cd                                     Weapon Desc  \
# count    292391.000000                                          292391
# unique             NaN                                              79
# top                NaN  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# freq               NaN                                          156686
# mean        363.123372                                             NaN
# min         101.000000                                             NaN
# 25%         310.000000                                             NaN
# 50%         400.000000                                             NaN
# 75%         400.000000                                             NaN
# max         516.000000                                             NaN
# std         123.700408                                             NaN
#
#         Status  Status Desc       Crm Cd 1      Crm Cd 2     Crm Cd 3  \
# count   838901       838901  838890.000000  61634.000000  2081.000000
# unique       6            6            NaN           NaN          NaN
# top         IC  Invest Cont            NaN           NaN          NaN
# freq    671291       671291            NaN           NaN          NaN
# mean       NaN          NaN     500.564774    957.544245   983.831331
# min        NaN          NaN     110.000000    210.000000   310.000000
# 25%        NaN          NaN     331.000000    998.000000   998.000000
# 50%        NaN          NaN     442.000000    998.000000   998.000000
# 75%        NaN          NaN     626.000000    998.000000   998.000000
# max        NaN          NaN     956.000000    999.000000   999.000000
# std        NaN          NaN     207.558394    111.323355    52.426413
#
#           Crm Cd 4                                LOCATION Cross Street  \
# count    61.000000                                  838901       133812
# unique         NaN                                   64053         9781
# top            NaN  800 N  ALAMEDA                      ST     BROADWAY
# freq           NaN                                    1527         2218
# mean    990.868852                                     NaN          NaN
# min     821.000000                                     NaN          NaN
# 25%     998.000000                                     NaN          NaN
# 50%     998.000000                                     NaN          NaN
# 75%     998.000000                                     NaN          NaN
# max     999.000000                                     NaN          NaN
# std      27.690236                                     NaN          NaN
#
#                   LAT            LON
# count   838901.000000  838901.000000
# unique            NaN            NaN
# top               NaN            NaN
# freq              NaN            NaN
# mean        33.981623    -118.034743
# min          0.000000    -118.667600
# 25%         34.013800    -118.429600
# 50%         34.058400    -118.321500
# 75%         34.163100    -118.273900
# max         34.334300       0.000000
# std          1.770806       6.139685

# %%
print(crime.columns)
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
# Check for missing values
crime.isnull().sum()
# Out:
# DR_NO                  0
# Date Rptd              0
# DATE OCC               0
# TIME OCC               0
# AREA                   0
# AREA NAME              0
# Rpt Dist No            0
# Part 1-2               0
# Crm Cd                 0
# Crm Cd Desc            0
# Mocodes           116254
# Vict Age               0
# Vict Sex          110555
# Vict Descent      110563
# Premis Cd             10
# Premis Desc          506
# Weapon Used Cd    546510
# Weapon Desc       546510
# Status                 0
# Status Desc            0
# Crm Cd 1              11
# Crm Cd 2          777267
# Crm Cd 3          836820
# Crm Cd 4          838840
# LOCATION               0
# Cross Street      705089
# LAT                    0
# LON                    0
# dtype: int64

# %%
# Dropping the 'cross_street' column since there is 705089 missing entries out of 838901,no crucial for my data analysis
crime.drop(columns=['Cross Street'], inplace=True)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Types of Crime
#
# What are the most common crime types, and how frequently do they occur?

# %%
# Calculate the count of each unique crime description in the 'crm_cd_desc'
crime_counts = crime['Crm Cd Desc'].value_counts()

# Display the count of occurrences for each unique crime description
print(crime_counts)
# Out:
# VEHICLE - STOLEN                                            89929
# BATTERY - SIMPLE ASSAULT                                    66925
# THEFT OF IDENTITY                                           52807
# BURGLARY FROM VEHICLE                                       51582
# BURGLARY                                                    51090
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)     51082
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT              48217
# THEFT PLAIN - PETTY ($950 & UNDER)                          42615
# INTIMATE PARTNER - SIMPLE ASSAULT                           42168
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)             32346
# THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)         30233
# ROBBERY                                                     28733
# THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD    27413
# VANDALISM - MISDEAMEANOR ($399 OR UNDER)                    22313
# SHOPLIFTING - PETTY THEFT ($950 & UNDER)                    19946
# CRIMINAL THREATS - NO WEAPON DISPLAYED                      17400
# BRANDISH WEAPON                                             13057
# TRESPASSING                                                 11933
# INTIMATE PARTNER - AGGRAVATED ASSAULT                       11411
# VIOLATION OF RESTRAINING ORDER                              10617
# BIKE - STOLEN                                                7022
# LETTERS, LEWD  -  TELEPHONE CALLS, LEWD                      6948
# OTHER MISCELLANEOUS CRIME                                    6048
# VIOLATION OF COURT ORDER                                     5785
# BUNCO, GRAND THEFT                                           5412
# ATTEMPTED ROBBERY                                            4371
# SHOPLIFTING-GRAND THEFT ($950.01 & OVER)                     4122
# OTHER ASSAULT                                                3886
# THEFT, PERSON                                                3755
# BATTERY WITH SEXUAL CONTACT                                  3724
# BURGLARY, ATTEMPTED                                          3510
# RAPE, FORCIBLE                                               3335
# EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)                   3334
# CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT                      3140
# VEHICLE - ATTEMPT STOLEN                                     2995
# DOCUMENT FORGERY / STOLEN FELONY                             2896
# CONTEMPT OF COURT                                            2470
# DISCHARGE FIREARMS/SHOTS FIRED                               2434
# PICKPOCKET                                                   2302
# ARSON                                                        2302
# BATTERY POLICE (SIMPLE)                                      2290
# BUNCO, PETTY THEFT                                           1836
# EXTORTION                                                    1793
# VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)     1743
# CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)     1556
# SHOTS FIRED AT INHABITED DWELLING                            1517
# CRIMINAL HOMICIDE                                            1426
# DISTURBING THE PEACE                                         1358
# FAILURE TO YIELD                                             1315
# SEXUAL PENETRATION W/FOREIGN OBJECT                          1189
# INDECENT EXPOSURE                                            1061
# CHILD NEGLECT (SEE 300 W.I.C.)                               1043
# ASSAULT WITH DEADLY WEAPON ON POLICE OFFIC
# GRAND THEFT / INSURANCE FRAUD                                   8
# MANSLAUGHTER, NEGLIGENT                                         7
# THEFT, COIN MACHINE - GRAND ($950.01 & OVER)                    7
# BRIBERY                                                         7
# PICKPOCKET, ATTEMPT                                             6
# TELEPHONE PROPERTY - DAMAGE                                     6
# BIKE - ATTEMPTED STOLEN                                         6
# BLOCKING DOOR INDUCTION CENTER                                  6
# THEFT, COIN MACHINE - ATTEMPT                                   5
# GRAND THEFT / AUTO REPAIR                                       5
# BIGAMY                                                          5
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)              5
# INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)                    5
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                        4
# FAILURE TO DISPERSE                                             3
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              2
# INCITING A RIOT                                                 1
# Name: Crm Cd Desc, dtype: int64

# %%
# Convert the crime counts to a dictionary for word cloud generation
crime_counts_dict = crime_counts.to_dict()

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(crime_counts_dict)

# Display the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Crime Type Word Cloud')

# Adding a description to the graph
plt.text(0.5, 0 , "Figure 1. The size of the crime type text is determined by its frequency of cases.", ha='center', va='center',  transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_type_wordcloud.png', bbox_inches='tight')

plt.show()

# %%
# Sort crime counts in descending order
sorted_counts = crime_counts.sort_values(ascending=False)

# Set a larger figure size for better visibility
plt.figure(figsize=(50, 10))

# Creating a bar plot of sorted crime counts
bars = sorted_counts.plot(kind='bar')


# Display count values on top of each bar
for bar, count in zip(bars.patches, sorted_counts):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')

# Title and axis labels
plt.title('Crime Occurance', fontsize=20)
plt.xlabel('Crime Type', fontsize=16)
plt.ylabel('Frequency', fontsize=16)

# Adding a description to the wordcloud
plt.text(0.5, -0.5, "Figure 2. This bar plot shows the different crime types and their respective occurences.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_types_and_frequency.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Top 10 crime types in Los Angeles, California

# %%
# Top 10 crime types and occurrences

crime_counts.head(10)
# Out:
# VEHICLE - STOLEN                                           89929
# BATTERY - SIMPLE ASSAULT                                   66925
# THEFT OF IDENTITY                                          52807
# BURGLARY FROM VEHICLE                                      51582
# BURGLARY                                                   51090
# VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)    51082
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT             48217
# THEFT PLAIN - PETTY ($950 & UNDER)                         42615
# INTIMATE PARTNER - SIMPLE ASSAULT                          42168
# THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)            32346
# Name: Crm Cd Desc, dtype: int64

# %%
# Convert the top 10 crime counts to a dictionary for word cloud generation
top_10_crime_counts_dict = crime_counts.head(10).to_dict()

# Create the word cloud for the top 10 crime types
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(top_10_crime_counts_dict)

# Display the word cloud for the top 10 crime types
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Remove axis
plt.title('Top 10 Crime Type Word Cloud')

# Adding a description to the wordcloud
plt.text(0.5, 0, "Figure 3. This word cloud shows the top 10 crime types and the size of the crime type text is determined by its frequency of cases.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/top_10_crime_wordcloud.png', bbox_inches='tight')

plt.show()

# %%
# Sort crime counts in descending order and select the top 10
top_10_crime_counts = crime_counts.head(10)

# Bar chart top 10

# Creating a bar plot of the top 10 crime counts
bars = top_10_crime_counts.plot(kind='bar')

# Display count values on top of each bar
for bar, count in zip(bars.patches, top_10_crime_counts):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')

# Title and axis labels
plt.title('Top 10 Crime Occurances')
plt.xlabel('Crime Type')
plt.ylabel('Frequency of Crime')

# Adding a description to the graph
plt.text(0.5, -1, "Figure 4. This bar plot shows the top 10 crime types and their respective occurences.", ha='center', va='center', fontsize=10, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/top_10_crime_types_and_frequency.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Weapons Used in Crimes
#
# Are weapons commonly employed in these incidents, and if so, which types are prevalent?

# %%
# Calculate the count of each unique weapon description in the 'weapon_desc'
weapon_counts = crime['Weapon Desc'].value_counts()

# Display the amount of time each unique weapon was used
print(weapon_counts)
# Out:
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    156686
# UNKNOWN WEAPON/OTHER WEAPON                        31160
# VERBAL THREAT                                      21450
# HAND GUN                                           18067
# SEMI-AUTOMATIC PISTOL                               6567
# KNIFE WITH BLADE 6INCHES OR LESS                    6189
# UNKNOWN FIREARM                                     5925
# OTHER KNIFE                                         5261
# MACE/PEPPER SPRAY                                   3331
# VEHICLE                                             2950
# ROCK/THROWN OBJECT                                  2479
# PIPE/METAL PIPE                                     2227
# BOTTLE                                              2183
# STICK                                               2061
# FOLDING KNIFE                                       2018
# CLUB/BAT                                            1919
# KITCHEN KNIFE                                       1711
# AIR PISTOL/REVOLVER/RIFLE/BB GUN                    1700
# KNIFE WITH BLADE OVER 6 INCHES IN LENGTH            1522
# BLUNT INSTRUMENT                                    1275
# HAMMER                                              1222
# SIMULATED GUN                                       1101
# REVOLVER                                            1082
# MACHETE                                             1052
# OTHER FIREARM                                        845
# OTHER CUTTING INSTRUMENT                             843
# PHYSICAL PRESENCE                                    817
# UNKNOWN TYPE CUTTING INSTRUMENT                      800
# SCREWDRIVER                                          724
# CONCRETE BLOCK/BRICK                                 642
# FIRE                                                 621
# BELT FLAILING INSTRUMENT/CHAIN                       606
# SCISSORS                                             605
# RIFLE                                                448
# FIXED OBJECT                                         385
# STUN GUN                                             364
# GLASS                                                299
# AXE                                                  296
# BOARD                                                285
# SHOTGUN                                              282
# CAUSTIC CHEMICAL/POISON                              224
# SWITCH BLADE                                         205
# BRASS KNUCKLES                                       188
# BOMB THREAT                                          150
# TOY GUN                                              150
# TIRE IRON                                            137
# SCALDING LIQUID                                      128
# SWORD                                                123
# RAZOR BLADE                                          103
# HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE         90
# DIRK/DAGGER                                           85
# EXPLOXIVE DEVICE                                      83
# ASSAULT WEAPON/UZI/AK47/ETC                           73
# DEMAND NOTE                                           63
# ICE PICK                                              62
# RAZOR                                                 53
# LIQUOR/DRUGS                                          51
# SEMI-AUTOMATIC RIFLE                                  48
# DOG/ANIMAL (SIC ANIMAL ON)                            48
# ROPE/LIGATURE                                         45
# STARTER PISTOL/REVOLVER                               37
# CLEAVER                                               34
# BOWIE KNIFE                                           30
# SAWED OFF RIFLE/SHOTGUN                               27
# AUTOMATIC WEAPON/SUB-MACHINE GUN                      26
# BOW AND ARROW                                         21
# SYRINGE                                               20
# STRAIGHT RAZOR                                        14
# MARTIAL ARTS WEAPONS                                  13
# UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE                  13
# BLACKJACK                                             12
# RELIC FIREARM                                         10
# UZI SEMIAUTOMATIC ASSAULT RIFLE                        9
# ANTIQUE FIREARM                                        8
# MAC-11 SEMIAUTOMATIC ASSAULT WEAPON                    3
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    2
# M1-1 SEMIAUTOMATIC ASSAULT RIFLE                       1
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          1
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# Name: Weapon Desc, dtype: int64

# %%
# Convert the weapons count to a dictionary for word cloud generation
weapon_counts_dict = weapon_counts.to_dict()

# Create the weapons word cloud
weapon_wordcloud = WordCloud(width=800, height=400, background_color='white', max_font_size=50000).generate_from_frequencies(weapon_counts_dict)

# Display the weapon word cloud
plt.figure(figsize=(10, 6))
plt.imshow(weapon_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Weapons Used Word Cloud')

# Adding a description to the graph
plt.text(0.5, 0 , "Figure 5. The size of the weapon description text is determined by its frequency of use.", ha='center', va='center',  transform=plt.gcf().transFigure)


# Save the plot as a PNG file
plt.savefig('../reports/figures/weapons_wordcloud.png', bbox_inches='tight')

plt.show()

# %%
# Creating a bar plot of weapon counts
plt.figure(figsize=(40, 10))
bars = weapon_counts.plot(kind='bar')

# Display count values on top of each bar
for bar, count in zip(bars.patches, weapon_counts):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom', fontsize=10)
                          

# Title and axis labels
plt.title('Weapon Use Frequency', fontsize=20)
plt.xlabel('Weapon Description', fontsize=16)
plt.ylabel('Frequency', fontsize=16)

# Adding a description to the wordcloud
plt.text(0.5, -0.4, "Figure 6. This bar plot shows the different weapons and their respective usage.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/weapons_usage.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Top 10 weapons use to commit a crime

# %%
# Top 10 weapons used

weapon_counts.head(10)
# Out:
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    156686
# UNKNOWN WEAPON/OTHER WEAPON                        31160
# VERBAL THREAT                                      21450
# HAND GUN                                           18067
# SEMI-AUTOMATIC PISTOL                               6567
# KNIFE WITH BLADE 6INCHES OR LESS                    6189
# UNKNOWN FIREARM                                     5925
# OTHER KNIFE                                         5261
# MACE/PEPPER SPRAY                                   3331
# VEHICLE                                             2950
# Name: Weapon Desc, dtype: int64

# %%
# Plotting the top 10 weapons used to commit a crime
top_5_weapons = weapon_counts.head(10)

plt.figure(figsize=(10, 6))
bars = top_5_weapons.plot(kind='bar')
plt.title('Top 10 Weapons')
plt.xlabel('Weapon Description')
plt.ylabel('Frequency')


# Display count values on top of each bar
for bar, count in zip(bars.patches, weapon_counts):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')

# Adding a description to the wordcloud
plt.text(0.5, -0.6, "Figure 7. This bar plot shows the top 10 weapons used to commit a crime.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)
    
# Save the plot as a PNG file
plt.savefig('../reports/figures/top_10_weapons.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Crime Analysis based on time

# %% [markdown]
# ### Crime by Year
#
# What is the crime rate by year? What is the crime trend? Is there more or less crime each year?

# %%
crime['Year'] = crime['DATE OCC'].dt.year

# Group by year and count the number of crimes
crime_by_year = crime.groupby('Year').size()

# Calculate crime rates
crime_rate_by_year = crime_by_year / crime_by_year.sum() * 1000  # Multiply by 1000 to get rates per 1000 people

# Plot the crime rates
plt.figure(figsize=(10, 6))
crime_rate_by_year.plot(kind='bar', color='skyblue')
plt.title('Crime Rates per 1000 People by Year')
plt.xlabel('Year')
plt.ylabel('Crime Rate per 1000 People')
plt.show()

# %%
crime['Year'] = crime['DATE OCC'].dt.year
crime['Month'] = crime['DATE OCC'].dt.month_name()

# Filter data for the years 2020, 2021, 2022, and 2023
filtered_crime = crime[crime['Year'].isin([2020, 2021, 2022, 2023])]

# Group by year and month, count the number of crimes
crime_by_year_month = filtered_crime.groupby(['Year', 'Month']).size().unstack()

# Ensure that the months are in the correct order
months_order = list(calendar.month_name)[1:]  # Starting from January
crime_rate_by_year_month = crime_by_year_month.reindex(months_order, axis=1)

# Calculate crime rates per month
crime_rate_by_year_month = crime_rate_by_year_month.div(crime_rate_by_year_month.sum(axis=1), axis=0) * 1000

# Plot the line graph
plt.figure(figsize=(12, 6))
for year in [2020, 2021, 2022, 2023]:
    plt.plot(crime_rate_by_year_month.loc[year], label=str(year), marker='o')

# Highlight the last record date in 2023
last_record_2023 = filtered_crime[filtered_crime['Year'] == 2023]['DATE OCC'].max()
if last_record_2023:
    last_record_month = last_record_2023.month_name()
    last_record_value = crime_rate_by_year_month.at[2023, last_record_month]
    plt.scatter([last_record_month], [last_record_value], color='red', marker='*', s=100, label='Last Record in 2023')

plt.title('Crime Rates per 1000 People by Year and Month')
plt.xlabel('Month')
plt.ylabel('Crime Rate per 1000 People')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.legend(title='Year')
plt.show()

# %% [markdown]
# ### Crime by Month
#
# When are crimes most prevalent throughout the year?

# %%
# Group incidents by month

# Extract month from 'DATE OCC' and create a new 'Month' column
crime['Month'] = crime['DATE OCC'].dt.month_name()

# Group incidents by month
crimes_by_month = crime['Month'].value_counts()

# Calculate the crime rate for each month
crime_rate_by_month = (crimes_by_month / len(crime)) * 100

print(crimes_by_month)
# Out:
# July         75372
# August       74976
# October      74628
# May          73304
# January      73092
# June         72853
# September    71904
# March        71166
# April        70270
# February     68662
# November     58899
# December     53775
# Name: Month, dtype: int64

# %%
# Extract month from 'DATE OCC' and create a new 'Month' column
crime['Month'] = crime['DATE OCC'].dt.month_name()

# Group incidents by month
crimes_by_month = crime['Month'].value_counts()

# Calculate the crime rate for each month
crime_rate_by_month = (crimes_by_month / len(crime)) * 100

# Plotting crime rate by month using Seaborn
plt.figure(figsize=(12, 10))
sns.barplot(x=crime_rate_by_month.index, y=crime_rate_by_month.values, color='skyblue')

# Display count values on top of each bar
for index, value in enumerate(crime_rate_by_month):
    plt.text(index, value + 0.2, f'{value:.2f}%', ha='center', va='bottom')

plt.title('Crime Rate by Month')
plt.xlabel('Month')
plt.ylabel('Crime Rate (%)')

# Adding a description to the bar graph
plt.text(0.5, -0.04, "Figure 8. This bar plot shows the crime rate for each month.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_rate_by_month.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Crime by Day of Week
#
# Is there any difference between weekday and weekend? What about the type of crime?

# %%
# Extract the day of the week from the 'date_occurred' column
crime['day_of_week'] = crime['DATE OCC'].dt.day_name()

# Calculate the total number of crimes per day of the week
total_crimes_per_day = crime['day_of_week'].value_counts()

# Calculate the percentage of crimes per day of the week
percentage_crimes_per_day = (total_crimes_per_day / total_crimes_per_day.sum()) * 100

# %%
# Sort days of the week in the correct order
days_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
percentage_crimes_per_day = percentage_crimes_per_day.reindex(days_order)

# Plot a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=percentage_crimes_per_day.index, y=percentage_crimes_per_day, palette='viridis')
plt.title('Percentage of Crime Per Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Percentage of Crime (%)')

# Adding a description to the bar graph
plt.text(0.5, -0.04, "Figure 9. This bar plot shows the percentage of crime per day of the week.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_day_week_bar.png', bbox_inches='tight')

plt.show()

# %%
# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(percentage_crimes_per_day, labels=percentage_crimes_per_day.index, autopct='%1.1f%%', startangle=90)
plt.title('Percentage of Crime Per Day of the Week')

# Adding a description to the bar graph
plt.text(0.5, -0.04, "Figure 10. This pie chart shows the percentage of crime per day of the week.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_day_week_pie.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Crime by Time of Day
#
# What times of the day witness higher crime incident rates?

# %%
# Convert the 'time_occurred' column to datetime format
crime['TIME OCC'] = pd.to_datetime(crime['TIME OCC'], format='%H:%M').dt.time


# Extract the hour from the 'time_occurred' column
crime['hour_of_day'] = crime['TIME OCC'].apply(lambda x: x.hour)

# Calculate the total number of crimes per hour of the day
total_crimes_per_hour = crime['hour_of_day'].value_counts().sort_index()

# %%
# Plot a bar chart for crime by time of day
plt.figure(figsize=(12, 6))
sns.barplot(x=total_crimes_per_hour.index, y=total_crimes_per_hour, color='skyblue')
plt.title('Crime by Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Crimes')

# Adding a description to the bar graph
plt.text(0.5, -0.04, "Figure 11. This bar plot shows the number of crimes per hour in a day.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_time_day.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Crime analysis based on the location

# %% [markdown]
# ### Crime by Location
#
# Which areas experience the highest rates of crime?
#
# Where do crimes typically occur, such as on the streets, in vehicles, buildings, or in the outskirts of the city?

# %%
# Map Displaying the crimes by location
# Create a base map centered at a specific location
crime_map = folium.Map(location=[34.052235, -118.243683], zoom_start=11)

# Create a Marker Cluster to group the crime locations
marker_cluster = MarkerCluster().add_to(crime_map)

# Iterate through the dataset to add markers for each crime location
for lat, lon in zip(crime['LAT'], crime['LON']):
    folium.Marker(location=[lat, lon], popup='Crime Scene').add_to(marker_cluster)

# Display the map
crime_map

# %%
# Calculate the count of each unique location in the 'area_name'
crime_location = crime['AREA NAME'].value_counts()

# Display the clocation of the crime scenes
print(crime_location)
# Out:
# Central        56587
# 77th Street    52838
# Pacific        49059
# Southwest      47062
# Hollywood      44396
# Southeast      42680
# Olympic        42315
# Newton         42087
# N Hollywood    41765
# Wilshire       39906
# Rampart        39356
# West LA        38518
# Northeast      36209
# Van Nuys       35548
# West Valley    35063
# Harbor         34622
# Topanga        34122
# Devonshire     33921
# Mission        33427
# Hollenbeck     31469
# Foothill       27951
# Name: AREA NAME, dtype: int64

# %%
# Plotting all areas with their crime rates
plt.figure(figsize=(20, 8))
bars = crime_location.plot(kind='bar')
plt.title('Crime Rates by Location')
plt.xlabel('Area')
plt.ylabel('Crime Count')

# Display count values on top of each bar
for bar, count in zip(bars.patches, crime_location):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')

# Adding a description to the wordcloud
plt.text(0.5, -0.1, "Figure 12. This bar plot shows the crime rates by location.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)
    
# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_rates_by_loaction.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Top 10 area with the highest crime rates in Los Angeles, California

# %%
# top 10 areas with the highest crime rates
crime_location.head(10)
# Out:
# Central        56587
# 77th Street    52838
# Pacific        49059
# Southwest      47062
# Hollywood      44396
# Southeast      42680
# Olympic        42315
# Newton         42087
# N Hollywood    41765
# Wilshire       39906
# Name: AREA NAME, dtype: int64

# %%
# Plotting the top 10 areas with the highest crime rates
top_10_crime_areas = crime_location.head(10)

plt.figure(figsize=(10, 6))
bars = top_10_crime_areas.plot(kind='bar')
plt.title('Top 10 Areas with Highest Crime Rates')
plt.xlabel('Area')
plt.ylabel('Crime Count')
plt.xticks(rotation=45)

# Display count values on top of each bar
for bar, count in zip(bars.patches, crime_location):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')

# Adding a description to the wordcloud
plt.text(0.5, -0.1, "Figure 13. This bar plot shows the top 10 areas with highest crime rates.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)
    
# Save the plot as a PNG file
plt.savefig('../reports/figures/top_10_area_with_highest_crime_rates.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Crime Analysis based on Demographic

# %% [markdown]
# ### Gender Disparities in Crime
#
# What is the distribution of crime victims by assigned sex?
#
# Is there a significant difference in victim count by sex?

# %% [markdown]
# F - Female
# M - Male
# X - Uknown

# %%
# Calculate the count of each unique victims sex in the 'vict_sex'
victims_sex = crime['Vict Sex'].value_counts()

# Display the sex of victims

print(victims_sex)
# Out:
# M    345942
# F    308734
# X     73578
# H        91
# -         1
# Name: Vict Sex, dtype: int64

# %%
# Pie chart to display the distribution of crime victims by sex

# Data for the pie chart
labels = victims_sex.index  # Victim sex categories (M, F, X)
sizes = victims_sex.values  # Counts of each victim sex category

# Pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Crime Victims by Sex')
plt.legend(labels, loc="best")

# Adding a description to the bar graph
plt.text(0.5, 0.1, "Figure 14. This pie chart shows the distribution of crime victims by sex.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/victims_sex_distribution.png', bbox_inches='tight')

plt.show()

# %%
# Compare the number victims by sex.

plt.figure()
bars = victims_sex.plot(kind='bar')
plt.title('Numbers of Victims by Sex')
plt.xlabel('Assigned Sex')
plt.ylabel('Crime Count')

# Display count values on top of each bar
for bar, count in zip(bars.patches, victims_sex):
    bars.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), count, ha='center', va='bottom')
    
# Adding a description to the bar graph
plt.text(0.5, -0.1, "Figure 15. This bar plot shows the number of victims by sex.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)
    
# Save the plot as a PNG file
plt.savefig('../reports/figures/victims_sex.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ### Age of Victims
#
# What is the statitical data on the ages of crime victims?

# %%
# Age of Victims
victims_age = crime['Vict Age'].value_counts()
print("Age of Victims")
print(victims_age)
# Out:
# Age of Victims
#  0      207614
#  30      19131
#  35      18702
#  31      18310
#  29      18245
#  28      17988
#  32      17782
#  33      17302
#  27      17270
#  26      16622
#  34      16503
#  25      16406
#  36      15560
#  24      15429
#  37      14880
#  38      14535
#  22      14027
#  39      13888
#  23      13726
#  40      13674
#  41      12819
#  21      12499
#  42      11949
#  43      11779
#  44      11144
#  50      10960
#  45      10881
#  20      10516
#  47      10162
#  46      10139
#  48       9575
#  49       9538
#  51       9476
#  52       9183
#  53       8949
#  19       8734
#  54       8547
#  55       8343
#  56       7833
#  57       7734
#  58       7435
#  59       7165
#  60       6965
#  61       6427
#  62       6124
#  63       5788
#  64       5443
#  18       5249
#  65       4974
#  66       4593
#  67       4097
#  17       3743
#  68       3641
#  16       3470
#  69       3254
#  15       3085
#  70       3022
#  71       2736
#  72       2584
#  14       2575
#  73       2373
#  13       2156
#  74       2062
#  75       1740
#  76       1624
#  12       1570
#  77       1429
#  78       1284
#  79       1081
#  11       1064
#  80        997
#  81        826
#  82        792
#  10        700
#  83        691
#  9         604
#  85        531
#  8         525
#  84        518
#  6         510
#  7         509
#  5         509
#  4         443
#  86        442
#  3         440
#  2         369
#  87        335
#  99        309
#  88        303
#  89        263
#  90        241
#  91        206
#  92        156
#  93        112
#  94         94
#  96         86
#  95         81
#  98         66
#  97         63
# -1          58
# -2          13
#  120         1
# -3           1
# Name: Vict Age, dtype: int64

# %%
# Clean the data
cleaned_data = crime[(crime['Vict Age'] > 0) & (crime['Vict Age'] <= 100)]

# Get the cleaned statistical summary
cleaned_victims_age = cleaned_data['Vict Age'].value_counts()

# Print the cleaned statistical summary
print("\nCleaned Age of Victims")
print(cleaned_victims_age)
# Out:
# Cleaned Age of Victims
# 30    19131
# 35    18702
# 31    18310
# 29    18245
# 28    17988
# 32    17782
# 33    17302
# 27    17270
# 26    16622
# 34    16503
# 25    16406
# 36    15560
# 24    15429
# 37    14880
# 38    14535
# 22    14027
# 39    13888
# 23    13726
# 40    13674
# 41    12819
# 21    12499
# 42    11949
# 43    11779
# 44    11144
# 50    10960
# 45    10881
# 20    10516
# 47    10162
# 46    10139
# 48     9575
# 49     9538
# 51     9476
# 52     9183
# 53     8949
# 19     8734
# 54     8547
# 55     8343
# 56     7833
# 57     7734
# 58     7435
# 59     7165
# 60     6965
# 61     6427
# 62     6124
# 63     5788
# 64     5443
# 18     5249
# 65     4974
# 66     4593
# 67     4097
# 17     3743
# 68     3641
# 16     3470
# 69     3254
# 15     3085
# 70     3022
# 71     2736
# 72     2584
# 14     2575
# 73     2373
# 13     2156
# 74     2062
# 75     1740
# 76     1624
# 12     1570
# 77     1429
# 78     1284
# 79     1081
# 11     1064
# 80      997
# 81      826
# 82      792
# 10      700
# 83      691
# 9       604
# 85      531
# 8       525
# 84      518
# 6       510
# 7       509
# 5       509
# 4       443
# 86      442
# 3       440
# 2       369
# 87      335
# 99      309
# 88      303
# 89      263
# 90      241
# 91      206
# 92      156
# 93      112
# 94       94
# 96       86
# 95       81
# 98       66
# 97       63
# Name: Vict Age, dtype: int64

# %%
# Display statistical data on the ages of crime victims
print("\nStatistical Data on Ages of Crime Victims:")

# The average age of victims
average_victims_age = cleaned_data['Vict Age'].mean()
print(f"\nAverage Age of Victims: {average_victims_age:.2f} years")

# The mode age of victims
mode_victims_age = cleaned_data['Vict Age'].mode()

# Check if there is more than one mode
if not mode_victims_age.empty:
    print(f"Mode Age(s) of Victims: {', '.join(map(str, mode_victims_age.values))} years")
else:
    print("No mode found for Victim Age.")

# The median age of victims
median_victims_age = cleaned_data['Vict Age'].median()
print(f"Median Age of Victims: {median_victims_age:.2f} years")
# Out:
# Statistical Data on Ages of Crime Victims:
#
# Average Age of Victims: 39.58 years
# Mode Age(s) of Victims: 30 years
# Median Age of Victims: 37.00 years

# %% [markdown]
# ### Ethnicity and Crime
#
# Which ethnic groups are most affected by crime?

# %% [markdown]
# Descent Code:
# A - Other Asian
# B - Black
# C - Chinese
# D - Cambodian
# F - Filipino
# G - Guamanian
# H - Hispanic/Latin/Mexican
# I - American Indian/Alaskan Native
# J - Japanese
# K - Korean
# L - Laotian
# O - Other
# P - Pacific Islander
# S - Samoan
# U - Hawaiian
# V - Vietnamese
# W - White
# X - Unknown
# Z - Asian Indian

# %%
# Extract ethnicity information for crime victims
victims_ethnicity = crime['Vict Descent'].value_counts()

print(victims_ethnicity)
# Out:
# H    257152
# W    170720
# B    119301
# X     81220
# O     66478
# A     18396
# K      4488
# F      3494
# C      3243
# J      1158
# V       870
# I       786
# Z       417
# P       225
# U       167
# D        64
# G        60
# L        51
# S        46
# -         2
# Name: Vict Descent, dtype: int64

# %%
# Pie chart to display the distribution of crime victims by ethnicity

# Data for the pie chart
labels = victims_ethnicity.index  # Victim ethnicity categories 
sizes = victims_ethnicity.values  # Counts of each victim ethnicity category


# Pie chart
plt.figure(figsize=(12, 10))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140,  wedgeprops=dict(width=0.8))



plt.title('Distribution of Crime Victims by Ethnicity',  fontsize=16, fontweight='bold')
plt.legend(labels, title='Ethnicity', bbox_to_anchor=(1,0.7), fontsize=10)

# Adding a description to the pie chart
plt.text(0.5, 0.1, "Figure 16. This pie chart shows the distribution of crime victims by ethnicity.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/victims_ethnicity_distribution.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Crime Resolution Status

# %%
# Crime resolution 
crime_resolution = crime['Status Desc'].value_counts()

# Bar chart for crime resolution
plt.figure(figsize=(12, 6))
sns.barplot(x=crime_resolution.index, y=crime_resolution, palette='viridis')
plt.title('Crime Resolution Status')
plt.xlabel('Resolution Type')
plt.ylabel('Number of Crimes')
plt.xticks(rotation=45, ha='right')

# Adding a description to the bar chart
plt.text(0.5, -0.1, "Figure 17. This bar chart shows the crime status.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_status.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# From the data we can assume that more adults commit crimes compare to juveniles, leading to adults been arrested at a higher rate than juveniles.

# %% [markdown]
# ### Crime Resolution Rate
#
# What is the percentage of solved cases versus open cases?

# %%
# Categories for solved and open cases
solved_cases = ['Adult Arrest', 'Juv Arrest']
open_cases = ['Invest Cont', 'Adult Other', 'Juv Other', 'UNK']

# Number of solved and open cases
solved_cases_count = crime_resolution.loc[solved_cases].sum()
open_cases_count = crime_resolution.loc[open_cases].sum()

# Calculate the percentage
percentage_solved_cases = (solved_cases_count / crime_resolution.sum()) * 100
percentage_open_cases = (open_cases_count / crime_resolution.sum()) * 100

# Print the percentages
print(f'Percentage of Solved Cases: {percentage_solved_cases:.2f}%')
print(f'Percentage of Open Cases: {percentage_open_cases:.2f}%')

# Pie chart for crime resolution
plt.figure(figsize=(8, 8))
plt.pie([solved_cases_count, open_cases_count], labels=['Solved Cases', 'Open Cases'], autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title('Crime Resolution Distribution')

# Adding a description to the pie chart
plt.text(0.5, -0.005, "Figure 18. This pie chart shows the crime resolution status.", ha='center', va='center', fontsize=16, transform=plt.gcf().transFigure)

# Save the plot as a PNG file
plt.savefig('../reports/figures/crime_resolution_rate.png', bbox_inches='tight')

plt.show()
# Out:
# Percentage of Solved Cases: 9.03%
# Percentage of Open Cases: 90.97%

# %% [markdown]
# We can see that most of the crime cases are open for investigation.

# %% [markdown]
# ### Response Time
#
# Examine the average response times of law enforcement to different types of incidents.

# %% [markdown]
# I aimed to understand the average response times of law enforcement to different types of incidents. Unfortunately, the dataset did not contain a direct column for law enforcement response times. As a workaround, I calculated the response time by subtracting the reported time from the time the incident occurred.

# %%
# Assuming 'DATE OCC', 'TIME OCC', and 'Date Rptd' are the columns representing incident date and time
crime['DATE OCC'] = pd.to_datetime(crime['DATE OCC'])
crime['TIME OCC'] = pd.to_datetime(crime['TIME OCC'], format='%H:%M:%S').dt.time
crime['Date Rptd'] = pd.to_datetime(crime['Date Rptd'])

# Calculate the response time
crime['Response Time'] = crime['Date Rptd'] - pd.to_datetime(crime['DATE OCC'].astype(str) + ' ' + crime['TIME OCC'].astype(str))

# Calculate the average response time for each type of incident
average_response_time_by_crime = crime.groupby('Crm Cd Desc')['Response Time'].mean()

# Display the average response time for each type of incident
print(average_response_time_by_crime)
# Out:
# Crm Cd Desc
# ARSON                                                        3 days 07:26:11.103388357
# ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER                 1 days 20:06:04.856860809
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAUL